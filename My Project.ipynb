# %%
import pandas as pd

df = pd.read_excel("HR_Analytics_Dataset.xlsx")
df.shape
# Out:
# (1000, 13)

# %%
display(df)
# Out:
#      EmployeeID  Age  Gender Department     JobRole  MonthlyIncome  \
# 0             1   38  Female      Sales     Manager          68347
# 1             2   33    Male         IT  Specialist          28372
# 2             3   37  Female    Finance     Analyst         139769
# 3             4   27    Male         HR    Engineer          30210
# 4             5   36    Male    Finance   Executive          65123
# ..          ...  ...     ...        ...         ...            ...
# 995         996   59    Male         HR     Analyst         139337
# 996         997   42  Female         HR     Manager          51696
# 997         998   37  Female         HR  Specialist          94758
# 998         999   60    Male         HR   Executive         142980
# 999        1000   57    Male         HR     Manager          62608
#
#      YearsAtCompany  TotalWorkingYears  JobSatisfaction Attrition Education  \
# 0                 2                 11                2        No   Diploma
# ...

# %%
df.head()
# Out:
#    EmployeeID  Age  Gender Department     JobRole  MonthlyIncome  \
# 0           1   38  Female      Sales     Manager          68347
# 1           2   33    Male         IT  Specialist          28372
# 2           3   37  Female    Finance     Analyst         139769
# 3           4   27    Male         HR    Engineer          30210
# 4           5   36    Male    Finance   Executive          65123
#
#    YearsAtCompany  TotalWorkingYears  JobSatisfaction Attrition Education  \
# 0               2                 11                2        No   Diploma
# 1               0                  8                3        No    Master
# 2               0                  0                1        No       MBA
# 3               3                  3                4        No  Bachelor
# 4               6                  9                4        No    Master
#
#   MaritalStatus   HireDate
# 0        Single 2022-03-13
# 1      Divorced 2018-11-02
# 2        Single 2017-04-02
# ...

# %%
df.tail()
# Out:
#      EmployeeID  Age  Gender Department     JobRole  MonthlyIncome  \
# 995         996   59    Male         HR     Analyst         139337
# 996         997   42  Female         HR     Manager          51696
# 997         998   37  Female         HR  Specialist          94758
# 998         999   60    Male         HR   Executive         142980
# 999        1000   57    Male         HR     Manager          62608
#
#      YearsAtCompany  TotalWorkingYears  JobSatisfaction Attrition Education  \
# 995               1                 19                1        No       MBA
# 996               1                  3                1        No       MBA
# 997               9                 15                3        No       PhD
# 998              20                 36                4        No       PhD
# 999              16                 16                3        No   Diploma
#
#     MaritalStatus   HireDate
# 995      Divorced 2019-11-03
# 996        Single 2024-01-21
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         1000 non-null   int64
#  1   Age                1000 non-null   int64
#  2   Gender             1000 non-null   object
#  3   Department         1000 non-null   object
#  4   JobRole            1000 non-null   object
#  5   MonthlyIncome      1000 non-null   int64
#  6   YearsAtCompany     1000 non-null   int64
#  7   TotalWorkingYears  1000 non-null   int64
#  8   JobSatisfaction    1000 non-null   int64
#  9   Attrition          1000 non-null   object
#  10  Education          1000 non-null   object
#  11  MaritalStatus      1000 non-null   object
#  12  HireDate           1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(6), object(6)
# memory usage: 101.7+ KB

# %%
df.describe()
# Out:
#         EmployeeID         Age  MonthlyIncome  YearsAtCompany  \
# count  1000.000000  1000.00000    1000.000000     1000.000000
# mean    500.500000    41.34800   88617.391000        4.972000
# min       1.000000    21.00000   25009.000000        0.000000
# 25%     250.750000    31.00000   57299.250000        1.000000
# 50%     500.500000    42.00000   89419.500000        3.000000
# 75%     750.250000    52.00000  120099.000000        7.000000
# max    1000.000000    60.00000  149964.000000       34.000000
# std     288.819436    11.42521   36171.197441        5.908649
#
#        TotalWorkingYears  JobSatisfaction                       HireDate
# count        1000.000000      1000.000000                           1000
# mean           10.121000         2.602000  2020-05-17 17:55:40.800000256
# min             0.000000         1.000000            2015-01-09 00:00:00
# 25%             3.000000         2.000000            2017-07-07 18:00:00
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Gender', 'Department', 'JobRole', 'MonthlyIncome',
#        'YearsAtCompany', 'TotalWorkingYears', 'JobSatisfaction', 'Attrition',
#        'Education', 'MaritalStatus', 'HireDate'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# EmployeeID           0
# Age                  0
# Gender               0
# Department           0
# JobRole              0
# MonthlyIncome        0
# YearsAtCompany       0
# TotalWorkingYears    0
# JobSatisfaction      0
# Attrition            0
# Education            0
# MaritalStatus        0
# HireDate             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
len(df)
# Out:
# 1000

# %%
df["MonthlyIncome"].mean()
# Out:
# np.float64(88617.391)

# %%
df["Age"].mean()
# Out:
# np.float64(41.348)

# %%
df["TotalWorkingYears"].mean()
# Out:
# np.float64(10.121)

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     819
# Yes    181
# Name: count, dtype: int64

# %%
(df["Attrition"] == "Yes").mean() * 100
# Out:
# np.float64(18.099999999999998)

# %%
df["Department"].value_counts()
# Out:
# Department
# Finance    218
# HR         212
# Sales      200
# R&D        192
# IT         178
# Name: count, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    511
# Male      489
# Name: count, dtype: int64

# %%
df["JobSatisfaction"].value_counts()
# Out:
# JobSatisfaction
# 4    276
# 3    262
# 2    250
# 1    212
# Name: count, dtype: int64

# %%
df.groupby("Department")["MonthlyIncome"].mean()
# Out:
# Department
# Finance    89431.683486
# HR         88333.702830
# IT         89506.207865
# R&D        86218.406250
# Sales      89542.500000
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby("Department")["TotalWorkingYears"].mean()
# Out:
# Department
# Finance    10.711009
# HR         10.523585
# IT          9.724719
# R&D         9.484375
# Sales      10.015000
# Name: TotalWorkingYears, dtype: float64

# %%
bins = [18,25,35,45,55,65]

labels = [
    "18-25",
    "26-35",
    "36-45",
    "46-55",
    "56-65"
]

df["AgeGroup"] = pd.cut(
    df["Age"],
    bins=bins,
    labels=labels
)

# %%
df["AgeGroup"].value_counts()
# Out:
# AgeGroup
# 46-55    256
# 36-45    253
# 26-35    249
# 56-65    142
# 18-25    100
# Name: count, dtype: int64

# %%
df["Department"].value_counts().plot(kind="bar")
plt.title("Employees by Department")
plt.show()

# %%
plt.hist(df["MonthlyIncome"], bins=20)
plt.title("Salary Distribution")
plt.show()

# %%
df["Gender"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Gender Distribution")
plt.show()

# %%
df["AgeGroup"].value_counts().plot(kind="bar")
plt.title("Employee Age Groups")
plt.show()
